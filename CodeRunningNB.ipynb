# %% [markdown]
# # Run Code
# ## print hello world
# print("Hello world!")

# %%
print("Hello world!")

# %% [markdown]
# ## Use pandas to create dataframe

# %%
import pandas as pd
print(pd.__version__)
data=[
    ["John", 30],
    ["Jane", 25],
    ["Bob", 40]]

df=pd.DataFrame(data, columns=["Name", "Age"])
display(df)
